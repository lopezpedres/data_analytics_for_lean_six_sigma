# %%
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import scipy as sp
import numpy as np
import random
from collections import Counter

# %%
#Getting our data
file = '_fb205379f16688a0d5fff594e91ac7e7_data_files_DA-LSS.xlsx'
df = pd.read_excel(file, header = 6, sheet_name = 3)
df

# %%
#Creating a piechart
#Ways to make it easier?
def pie(L):
    C = Counter(L) #By doing this we can have the count of each categorical value
    return plt.pie(labels = C.keys(), x = C.values())
pie(df.Reclaim)
# Out:
# ([<matplotlib.patches.Wedge at 0x2417424b8b0>,
#   <matplotlib.patches.Wedge at 0x2417424bd90>,
#   <matplotlib.patches.Wedge at 0x2417425b250>,
#   <matplotlib.patches.Wedge at 0x2417425b6d0>,
#   <matplotlib.patches.Wedge at 0x2417425baf0>,
#   <matplotlib.patches.Wedge at 0x2417425bf70>,
#   <matplotlib.patches.Wedge at 0x24174268430>,
#   <matplotlib.patches.Wedge at 0x241742688b0>],
#  [Text(1.0868966851805422, 0.16927963771094706, 'Account closing'),
#   Text(0.8798231659202305, 0.6602357129920365, 'IBAN'),
#   Text(-0.05662661422930982, 1.0985414996989988, 'Status info'),
#   Text(-1.0941698611796713, 0.11310311616422995, 'Matching'),
#   Text(-0.4663058228997005, -0.9962724926092427, 'Billing'),
#   Text(0.388027310607237, -1.0292884951377408, 'Recalls'),
#   Text(0.8965311783609239, -0.6373631980486271, 'Stop payment'),
#   Text(1.0821777475632626, -0.1972088301240685, 'EB Contract')])

# %%
#Creating a char bar
ax=sns.barplot(x = list(C.keys()), y = list( C.values()), fi ) #optinal
ax.set_xticklabels(ax.get_xticklabels(), font())
# Out:
# [Text(0, 0, 'Account closing'),
#  Text(1, 0, 'IBAN'),
#  Text(2, 0, 'Status info'),
#  Text(3, 0, 'Matching'),
#  Text(4, 0, 'Billing'),
#  Text(5, 0, 'Recalls'),
#  Text(6, 0, 'Stop payment'),
#  Text(7, 0, 'EB Contract')]
